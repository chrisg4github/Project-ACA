# %%
#Dependencies

from matplotlib.figure import Figure 
import matplotlib.pyplot as plt 
import matplotlib.dates as mdates 
import pandas as pd 
import numpy as np 
import datetime as dt 
import seaborn as sns 
np.random.seed(sum(map(ord, "aesthetics")))

# %%
# Store filepath in a variable ,parse_dates=["date"]
# FIPS is Federal Information Processing Standards Code
# GNIS is Geographic Name Information System

state = "../data/usa_state_abv.csv"
# Read our Data file with the pandas library
state_df = pd.read_csv(state,dtype=object)
state_df.describe()
state_df.info()
state_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 4 columns):
# FIPS_CODE     57 non-null object
# STUSAB        57 non-null object
# STATE_NAME    57 non-null object
# GNIS_CODE     57 non-null object
# dtypes: object(4)
# memory usage: 1.9+ KB
#    FIPS_CODE STUSAB                   STATE_NAME GNIS_CODE
# 0         01     AL                      Alabama  01779775
# 1         02     AK                       Alaska  01785533
# 2         04     AZ                      Arizona  01779777
# 3         05     AR                     Arkansas  00068085
# 4         06     CA                   California  01779778
# 5         08     CO                     Colorado  01779779
# 6         09     CT                  Connecticut  01779780
# 7         10     DE                     Delaware  01779781
# 8         11     DC         District of Columbia  01702382
# 9         12     FL                      Florida  00294478
# ...

# %%
# Store filepath in a variable ,parse_dates=["date"]
coverage = "../data/Coverage_Gains_ACA_state_data_12_2016.csv"
# Read our Data file with the pandas library
coverage_df = pd.read_csv(coverage)
coverage_df.describe()
coverage_df.info()
coverage_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
# State                                                         51 non-null object
# Uninsured Rate (2010, %)                                      51 non-null float64
# Uninsured Rate (2015, %)                                      51 non-null float64
# Percentage Point Decrease in Uninsured Rate (2010-2015, %)    51 non-null float64
# People Gaining Coverage (2010-2015, %)                        51 non-null object
# dtypes: float64(3), object(2)
# memory usage: 2.2+ KB
#         State  Uninsured Rate (2010, %)  Uninsured Rate (2015, %)  \
# 0    Alabama                       14.6                      10.1
# 1     Alaska                       19.9                      14.9
# 2    Arizona                       16.9                      10.8
# 3   Arkansas                       17.5                       9.5
# 4  California                      18.5                       8.6
#
# ...

# %%
# Store filepath in a variable ,parse_dates=["date"]
emp_coverage = "../data/Employer_Coverage_ACA_state_data_12_2016_short_headers.csv"
# Read our Data file with the pandas library
emp_coverage_df = pd.read_csv(emp_coverage)
emp_coverage_df.describe()
emp_coverage_df.info()
emp_coverage_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 24 columns):
# State                                                               51 non-null object
# People with Employer Coverage (2015)                                51 non-null object
# Gained Coverage by Staying on Parents' Plan Until Age 26 (2013)     51 non-null object
# Total with Lifetime Limit on health benefits pre-ACA (2008-2010)    51 non-null object
# Children with Lifetime Limit on benefits pre-ACA (2008-2010)        51 non-null object
# Adult Males with Lifetime Limit on benefits pre-ACA (2008-2010)     51 non-null object
# Adult Females w. Lifetime Limit on benefits pre-ACA (2008-2010)     51 non-null object
# Total w. Priv. Cov. No Cost Sharing for Prev. Serv. (2013-2015)     51 non-null object
# Kids w. Priv. Cov. No Cost Sharing for Prev. Serv. (2013-2015)      51 non-null object
# Males w. Pri. Cov. No Cost Sharing for Prev. Serv. (2013-2015)      51 non-null object
# ...

# %%
# Store filepath in a variable ,parse_dates=["date"]
idv_coverage = "../data/Individual_Market_Coverage_ACA_state_data_12_2016_short_headers.csv"
# Read our Data file with the pandas library
idv_coverage_df = pd.read_csv(idv_coverage)
idv_coverage_df.describe()
idv_coverage_df.info()
idv_coverage_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 13 columns):
# State                                                               51 non-null object
# Individuals with Pre-Existing Condition (2009)                      51 non-null object
# Individuals Selecting a Marketplace Plan (2016)                     51 non-null object
# Individuals with Marketplace Coverage (Q1 2016)                     51 non-null object
# Individuals Receiving Tax Credits (Q1 2016)                         51 non-null object
# Avg. Monthly Tax Credit for those Receiving Credits (Q1 2016)       51 non-null object
# Individuals Receiving Cost Sharing Reductions (Q1 2016)             51 non-null object
# Average Number of Marketplace Plans Available (2017)                51 non-null object
# Marketplace Consumers who Could Select Plan for < $75 (2017)        51 non-null object
# Marketplace Consumers who Could Select a Plan for < $100 (2017)     51 non-null object
# ...

# %%
# Store filepath in a variable ,parse_dates=["date"]
caid_coverage = "../data/Medicaid_ACA_state_data_12_2016_short_headers.csv"
# Read our Data file with the pandas library
caid_coverage_df = pd.read_csv(caid_coverage)
caid_coverage_df.describe()
caid_coverage_df.info()
caid_coverage_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 25 columns):
# State                                                               51 non-null object
# Total Medicaid and CHIP Enrollment (July - Sept. 2013)              51 non-null object
# Total Medicaid and CHIP Enrollment (August 2016)                    51 non-null object
# Total Medicaid/CHIP Child Enrollment (August 2016)                  51 non-null object
# Change in total Medicaid and CHIP Coverage (2013 - 2016)            51 non-null object
# Dually Eligible for full Medicaid and Medicare (Dec. 2015)          51 non-null object
# Dually Eligible for partial Medicaid and Medicare (Dec. 2015)       51 non-null object
# Dually Eligible for Full or Partial Caid and Care (Dec. 2015)       51 non-null object
# State Has Expanded (as of Dec. 2016)                                51 non-null object
# Increased in Covered due to Expansion (2016, if all expanded)       51 non-null object
# ...

# %%
# Store filepath in a variable ,parse_dates=["date"]
care_coverage = "../data/Medicare_ACA_state_data_12_2016.csv"
# Read our Data file with the pandas library
care_coverage_df = pd.read_csv(care_coverage)
care_coverage_df.describe()
care_coverage_df.info()
care_coverage_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 10 columns):
# State                                                                              51 non-null object
# Medicare Enrollment (Sept. 2016)                                                   51 non-null object
# Medicare Beneficiaries benefitting from donut hole savings (2015)                  51 non-null object
# Total Medicare beneficiary savings from donut hole (2015)                          51 non-null object
# Average per Medicare Beneficiary Donut Hole Savings (2015)                         51 non-null object
# Part B Beneficiaries Using Free Preventive Services (2015)                         51 non-null object
# Share of Part B Beneficiaries Using Free Preventive Services (2015)                51 non-null object
# % Change in Hospital Readmission Rates Among Medicare Beneficiaries (2010-2015)    51 non-null float64
# ...

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns


# # Load data
# path = '/../'

# with open('%sCovGains.csv' % path) as f:
#     df = pd.read_csv(f)

# states = pd.read_csv('https://query.data.world/s/bkbonapg553rwy1riqjqqdm9f')


# add state abbreviations
# states.drop([47, 48, 49, 50, 51, 52], axis=0, inplace=True)
# states = states.sort_values(by='STATE_NAME')
# states=states.reset_index(drop=True)

# df['StateAbb'] = states.STUSAB
# df = df[:51]


# # plot

# sns.set_style('ticks')

# f, ax = plt.subplots(figsize=(10, 18))

# df = df.sort_values(by='UninsuredRate2015', ascending=False)

# sns.set_color_codes("pastel")
# sns.barplot(x='UninsuredRate2010', y='StateAbb', data=df, label='2010', color='b')

# sns.set_color_codes("muted")
# sns.barplot(x='UninsuredRate2015', y='StateAbb', data=df, label='2015', color='b')

# ax.legend(ncol=2, loc="lower right", frameon=True, fontsize=14)

# plt.grid(alpha=0.5, linestyle='dashed')
# ax.set_ylabel('')
# ax.set_xlabel('Percent Uninsured', fontsize=18)
# plt.yticks(fontsize=15)
# locs, labels = plt.xticks()
# plt.xticks(locs[1:], ['5%', '10%', '15%', '20%', '25%'], fontsize=15)
# ax.yaxis.set_ticks_position('left')
# ax.xaxis.set_ticks_position('bottom')
# ax.set_title('Uninsured Rates (healthcare) by State\n2010 vs 2015', fontsize=22)
# ax.spines['right'].set_visible(False)
# ax.spines['top'].set_visible(False)

# plt.show()
